# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
def dataset(x, missing = ""):
    return pd.read_csv('Dataset/' + x + '.csv', sep = ';', low_memory = False, na_values = missing_values).rename(str.strip, axis = 'columns')

# %%
missing_values = ['?']
account_data = dataset('account', missing_values)
client_data = dataset('client', missing_values)
disp_data = dataset('disp', missing_values)
district_data = dataset('district', missing_values)
card_train = dataset('card_train', missing_values)
card_test = dataset('card_test')
loan_train = dataset('loan_train', missing_values)
loan_test = dataset('loan_test')
trans_train = dataset('trans_train', missing_values)
trans_test = dataset('trans_test')

# %%
# Removing name and region from district
district_data.drop(['name', 'region'], axis=1, inplace=True)

# only owner can issue permanent orders and ask for a loan
disp_owners = disp_data[disp_data.type.eq('OWNER')]

# %%
# Normalize birthday dates and add a new column (Genre) to distinguish

new_col = []
i = 0
for line in client_data['birth_number']:
    if int(str(line)[2]) >= 5:
        client_data['birth_number'][i] = client_data['birth_number'][i] - 5000
        new_col.append('F')
    else:
        new_col.append('M')
    i+=1
        
client_data['Genre'] = new_col

# %%
# build train dataset

train_data = client_data
train_data = pd.merge(train_data, disp_owners, left_on = 'client_id', right_on = 'client_id', suffixes = ('_client', '_disp'))
train_data = pd.merge(train_data, card_train, left_on = 'disp_id', right_on = 'disp_id', suffixes = ('', '_card'), how='outer')
train_data = pd.merge(train_data, district_data.set_index('code'), left_on = 'district_id', right_index = True)
train_data = pd.merge(train_data, account_data, left_on = 'account_id', right_on = 'account_id', suffixes = ('', '_account'))
train_data = pd.merge(train_data, loan_train, left_on = 'account_id', right_on = 'account_id', how="outer")
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4500 entries, 0 to 4499
# Data columns (total 32 columns):
# client_id                                           4500 non-null int64
# birth_number                                        4500 non-null int64
# district_id                                         4500 non-null int64
# Genre                                               4500 non-null object
# disp_id                                             4500 non-null int64
# account_id                                          4500 non-null int64
# type                                                4500 non-null object
# card_id                                             177 non-null float64
# type_card                                           177 non-null object
# issued                                              177 non-null float64
# no. of inhabitants                                  4500 non-null int64
# ...

# %%
# build test dataset

test_data = client_data
test_data = pd.merge(test_data, disp_owners, left_on = 'client_id', right_on = 'client_id', suffixes = ('_client', '_disp'))
test_data = pd.merge(test_data, card_test, left_on = 'disp_id', right_on = 'disp_id', suffixes = ('', '_card'), how='outer')
test_data = pd.merge(test_data, district_data.set_index('code'), left_on = 'district_id', right_index = True)
test_data = pd.merge(test_data, account_data, left_on = 'account_id', right_on = 'account_id', suffixes = ('', '_account'))
test_data = pd.merge(test_data, loan_test, left_on = 'account_id', right_on = 'account_id', how="outer")
test_data.info()

train_data = pd.get_dummies(train_data, columns=['frequency'], dtype=bool)
test_data = pd.get_dummies(test_data, columns=['frequency'], dtype=bool)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4500 entries, 0 to 4499
# Data columns (total 32 columns):
# client_id                                           4500 non-null int64
# birth_number                                        4500 non-null int64
# district_id                                         4500 non-null int64
# Genre                                               4500 non-null object
# disp_id                                             4500 non-null int64
# account_id                                          4500 non-null int64
# type                                                4500 non-null object
# card_id                                             25 non-null float64
# type_card                                           25 non-null object
# issued                                              25 non-null float64
# no. of inhabitants                                  4500 non-null int64
# ...

# %%
# Dropping ids
train_data_no_ids = train_data.drop(['loan_id', 'account_id', 'district_id', 'disp_id', 'client_id', 'card_id'], axis=1)

# Create correlation matrix
corr_matrix = train_data_no_ids.corr().abs()
plt.figure(figsize = (20,6))
sb.heatmap(corr_matrix, annot=True)

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Drop features 
train_data_no_ids.drop(to_drop, axis=1, inplace=True)

print("{} Dropped columns: {}".format(len(to_drop), to_drop) )
# Out:
# 3 Dropped columns: ["unemploymant rate '96", "no. of commited crimes '95", "no. of commited crimes '96"]
